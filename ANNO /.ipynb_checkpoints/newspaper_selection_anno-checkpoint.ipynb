# %%
import pandas as pd
import numpy as np
from pathlib import Path

import matplotlib.pyplot as plt

pd.set_option("display.max_rows", 50)
pd.set_option("display.max_colwidth", 80)

# %%
# Pfad anpassen, falls deine Datei anders heißt
DATA_PATH = Path("metadata.csv")

df = pd.read_csv(DATA_PATH)

# Sicherstellen, dass 'date' als String vorliegt und Jahr extrahieren
df["date"] = df["date"].astype(str)
df["year"] = df["date"].str[:4].astype(int)

df.head()
# Out:
#    aid         title      date  year
# 0  zub  12 Uhr Blatt  19330531  1933
# 1  zub  12 Uhr Blatt  19330601  1933
# 2  zub  12 Uhr Blatt  19330602  1933
# 3  zub  12 Uhr Blatt  19330603  1933
# 4  zub  12 Uhr Blatt  19330606  1933

# %%
# Für jeden Titel: erste Jahr, letztes Jahr, Anzahl unterschiedlicher Jahre
coverage_per_title = (
    df.groupby("title")["year"]
      .agg(start_jahr="min", end_jahr="max", anzahl_jahre=lambda x: x.nunique())
      .reset_index()
)

coverage_per_title.sort_values("anzahl_jahre", ascending=False).head(50)
# Out:
#                                                                             title  \
# 284                                                                Wiener Zeitung
# 287                                                          Wienerisches Diarium
# 185                                          Neues Wiener Tagblatt (Tagesausgabe)
# 190                          Neuigkeits-Welt-Blatt (Provinz-Ausgabe/Land-Ausgabe)
# 203                                                          Pharmaceutische Post
# 176                                                             Neue Freie Presse
# 291                           Österreichisch-Ungarische Buchhändler-Correspondenz
# 300                                     Österreichische Buchhändler-Correspondenz
# 13                             Anzeiger für den Buch-, Kunst und Musicalienhandel
# 275                                              Wiener Sonn- und Montags-Zeitung
# 276                                                       Wiener Sonntags-Zeitung
# 35                                                         Das interessante Blatt
# 258                                                           Wiener Illustrierte
# 274                                                             Wiener Salonblatt
# 158                                                                      Kikeriki
# 240                                                 Volksblatt für Stadt und Land
# 122                                                             Feuerwehr-Signale
# 14                                                               Arbeiter-Zeitung
# 115  Drogisten-Zeitung: Organ des Allgemeinen Österreichischen Drogistenvereines.
# 304                                        Österreichische Forst- und Jagdzeitung
# 294                                                 Österreichische  Forstzeitung
# 285                                      Wiener allgemeine Forst- und Jagdzeitung
# 6                                                         Allgemeine Forstzeitung
# 83                                                                      Die Bombe
# 249                                                     Wiener Allgemeine Zeitung
# 24                   Correspondenz-Blatt für den katholischen Clerus Oesterreichs
# 263                                            Wiener Landwirtschaftliche Zeitung
# 180                                                   Neue Wiener Friseur-Zeitung
# 313                                    Österreichische Zeitschrift für Verwaltung
# 272                                        Wiener Neueste Nachrichten <1894-1919>
# 299                                           Österreichische Buchdrucker-Zeitung
# 230                 Theaterzettel des Hof-Operntheaters / Staatsoper (tit. fict.)
# 200                                             Oesterreichischer Soldatenfreund.
# 167                                                          Militärische Zeitung
# 164                                                               Militär-Zeitung
# 184                                 Neues Wiener Journal: unparteiisches Tagblatt
# 179                                                          Neue Militär-Zeitung
# 213                                                                    Reichspost
# 140                                                              Hebammen-Zeitung
# 204                                                        Pharmaceutische Presse
# 123                                                                        Figaro
# 305                                          Österreichische Illustrierte Zeitung
# 252                                                            Wiener Caricaturen
# 250                                                                 Wiener Bilder
# 18                                                        Bade- und Reise-Journal
# 128                                                                     Freiheit!
# 194                                             Oesterreichische Arbeiter-Zeitung
# 22                                            Christlich-sociale Arbeiter-Zeitung
# 26                                                          Danzers Armee-Zeitung
# 32                                                                  Das Vaterland
#
#      start_jahr  end_jahr  anzahl_jahre
# 284        1871      1954            80
# 287        1871      1954            80
# 185        1871      1945            71
# 190        1874      1943            70
# 203        1871      1942            70
# 176        1871      1939            69
# 291        1871      1950            67
# 300        1871      1950            67
# 13         1871      1950            67
# 275        1871      1936            65
# 276        1871      1936            65
# 35         1882      1944            63
# 258        1882      1944            63
# 274        1872      1938            63
# 158        1871      1933            62
# 240        1871      1933            61
# 122        1883      1943            60
# 14         1889      1954            59
# 115        1886      1943            58
# 304        1883      1939            57
# 294        1883      1939            57
# 285        1883      1939            57
# 6          1883      1939            57
# 83         1871      1925            55
# 249        1880      1934            55
# 24         1882      1939            54
# 263        1879      1932            54
# 180        1890      1943            54
# 313        1871      1920            50
# 272        1894      1943            50
# 299        1873      1920            48
# 230        1899      1946            48
# 200        1872      1919            47
# 167        1872      1919            47
# 164        1872      1919            47
# 184        1893      1939            47
# 179        1872      1919            47
# 213        1893      1938            46
# 140        1887      1934            46
# 204        1891      1938            45
# 123        1871      1919            45
# 305        1894      1938            45
# 252        1881      1925            45
# 250        1896      1939            44
# 18         1876      1931            43
# 128        1895      1938            42
# 194        1895      1938            42
# 22         1895      1938            42
# 26         1896      1938            42
# 32         1871      1911            41

# %%
selected_titles = [
    "Wiener Zeitung",
    "Wienerisches Diarium",
    "Neues Wiener Tagblatt (Tagesausgabe)",
    "Neues Wiener Tagblatt (Wochenausgabe)",
    "Arbeiter-Zeitung",
    "Christlich-sociale Arbeiter-Zeitung",
    "Oesterreichische Arbeiter-Zeitung",
    "Deutsche Arbeiter-Zeitung",
    "Neue Freie Presse",
    "Das Vaterland",
    "Neues Österreich",
]

coverage_sel = coverage_per_title[
    coverage_per_title["title"].isin(selected_titles)
].copy()

coverage_sel.sort_values("start_jahr")
# Out:
#                                      title  start_jahr  end_jahr  anzahl_jahre
# 32                           Das Vaterland        1871      1911            41
# 176                      Neue Freie Presse        1871      1939            69
# 185   Neues Wiener Tagblatt (Tagesausgabe)        1871      1945            71
# 284                         Wiener Zeitung        1871      1954            80
# 287                   Wienerisches Diarium        1871      1954            80
# 14                        Arbeiter-Zeitung        1889      1954            59
# 22     Christlich-sociale Arbeiter-Zeitung        1895      1938            42
# 194      Oesterreichische Arbeiter-Zeitung        1895      1938            42
# 73               Deutsche Arbeiter-Zeitung        1913      1935            20
# 186  Neues Wiener Tagblatt (Wochenausgabe)        1932      1942             7
# 188                       Neues Österreich        1945      1954            10

# %%
# Mapping: Zeitungsfamilie -> Einzeltitel
families = {
    "Wiener Zeitung": [
        "Wiener Zeitung",
        "Wienerisches Diarium",
    ],
    "Neues Wiener Tagblatt": [
        "Neues Wiener Tagblatt (Tagesausgabe)",
        "Neues Wiener Tagblatt (Wochenausgabe)",
    ],
    "Arbeiter-Zeitung": [
        "Arbeiter-Zeitung",
        "Christlich-sociale Arbeiter-Zeitung",
        "Oesterreichische Arbeiter-Zeitung",
        "Deutsche Arbeiter-Zeitung",
    ],
    "Neue Freie Presse": [
        "Neue Freie Presse",
    ],
    "Das Vaterland": [
        "Das Vaterland",
    ],
    "Neues Österreich": [
        "Neues Österreich",
    ],
}

# %%
family_rows = []

for fam_name, titles in families.items():
    sub = df[df["title"].isin(titles)]
    years = sorted(sub["year"].unique())
    if not years:
        continue

    family_rows.append({
        "familie": fam_name,
        "titel_anzahl": len(titles),
        "start_jahr": years[0],
        "end_jahr": years[-1],
        "anzahl_jahre": len(years),
    })

coverage_families = pd.DataFrame(family_rows)
coverage_families.sort_values("start_jahr")
# Out:
#                  familie  titel_anzahl  start_jahr  end_jahr  anzahl_jahre
# 0         Wiener Zeitung             2        1871      1954            80
# 1  Neues Wiener Tagblatt             2        1871      1945            71
# 3      Neue Freie Presse             1        1871      1939            69
# 4          Das Vaterland             1        1871      1911            41
# 2       Arbeiter-Zeitung             4        1889      1954            60
# 5       Neues Österreich             1        1945      1954            10

# %%
coverage_families.sort_values("anzahl_jahre", ascending=False)
# Out:
#                  familie  titel_anzahl  start_jahr  end_jahr  anzahl_jahre
# 0         Wiener Zeitung             2        1871      1954            80
# 1  Neues Wiener Tagblatt             2        1871      1945            71
# 3      Neue Freie Presse             1        1871      1939            69
# 2       Arbeiter-Zeitung             4        1889      1954            60
# 4          Das Vaterland             1        1871      1911            41
# 5       Neues Österreich             1        1945      1954            10

# %%
# Hilfsspalte Dekade (z.B. 1870, 1880, ...)
df["dekade"] = (df["year"] // 10) * 10

rows = []
for fam_name, titles in families.items():
    sub = df[df["title"].isin(titles)]
    dekaden = sub.groupby("dekade")["year"].nunique().reset_index(name="anzahl_jahre")
    dekaden["familie"] = fam_name
    rows.append(dekaden)

dekaden_fam = pd.concat(rows, ignore_index=True)

# Pivot: Dekade x Familie -> Anzahl Jahre mit Ausgaben
pivot_dekaden = dekaden_fam.pivot_table(
    index="dekade",
    columns="familie",
    values="anzahl_jahre",
    fill_value=0
).sort_index()

pivot_dekaden
# Out:
# familie  Arbeiter-Zeitung  Das Vaterland  Neue Freie Presse  \
# dekade
# 1870                  0.0            9.0                9.0
# 1880                  1.0           10.0               10.0
# 1890                 10.0           10.0               10.0
# 1900                 10.0           10.0               10.0
# 1910                 10.0            2.0               10.0
# 1920                 10.0            0.0               10.0
# 1930                  9.0            0.0               10.0
# 1940                  5.0            0.0                0.0
# 1950                  5.0            0.0                0.0
#
# familie  Neues Wiener Tagblatt  Neues Österreich  Wiener Zeitung
# dekade
# 1870                       8.0               0.0             9.0
# 1880                       7.0               0.0            10.0
# 1890                      10.0               0.0            10.0
# 1900                      10.0               0.0            10.0
# 1910                      10.0               0.0            10.0
# 1920                      10.0               0.0            10.0
# 1930                      10.0               0.0            10.0
# 1940                       6.0               5.0             6.0
# 1950                       0.0               5.0             5.0

# %%
# Einfacher Linienplot pro Familie über die Zeit (Dekaden)

plt.figure(figsize=(10, 6))

for fam in pivot_dekaden.columns:
    plt.plot(pivot_dekaden.index, pivot_dekaden[fam], marker="o", label=fam)

plt.xlabel("Dekade")
plt.ylabel("Anzahl Jahre mit Ausgaben")
plt.title("Dekadenweise Abdeckung pro Zeitungsfamilie (ANNO, 1870–1950er)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def summarize_family(row):
    return (
        f"{row['familie']}: {int(row['start_jahr'])}–{int(row['end_jahr'])} "
        f"({int(row['anzahl_jahre'])} Jahre)"
    )

for _, r in coverage_families.sort_values("start_jahr").iterrows():
    print("-", summarize_family(r))
# Out:
# - Wiener Zeitung: 1871–1954 (80 Jahre)
# - Neues Wiener Tagblatt: 1871–1945 (71 Jahre)
# - Neue Freie Presse: 1871–1939 (69 Jahre)
# - Das Vaterland: 1871–1911 (41 Jahre)
# - Arbeiter-Zeitung: 1889–1954 (60 Jahre)
# - Neues Österreich: 1945–1954 (10 Jahre)
